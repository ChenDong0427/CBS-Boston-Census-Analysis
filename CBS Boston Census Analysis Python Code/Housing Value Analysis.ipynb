# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_path = '/content/drive/MyDrive/CS506 Project/Deliverable 1/data/Owner-occupied housing value.csv'

# %%
df = pd.read_csv(data_path)
detailed_price = df.iloc[:, 1:-1]

# %%
column_name = ('2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019')
y_offset = np.zeros(len(columns))
labels = detailed_price.columns
plt.figure(figsize=(10, 10))
for index, column in detailed_price[::-1].iteritems():
  plt.bar(column_name, column.values, bottom=y_offset, width=0.4, label=index)
  y_offset = y_offset + column.values


plt.legend(bbox_to_anchor=(1,0.9), loc='center left')
plt.title('Housing Value in Boston from 2010 to 2019')
plt.show()
# plt.savefig("Housing_Value_Detail.png")

# %%
plt.plot(column_name, df['Median'][::-1], 'o-')
plt.title('Median of Housing Value in Boston from 2010 to 2019')
plt.show()
# plt.savefig("Housing_Value_Median.png")
